# %%
#Dost
#find the companies that fell below 1.8 ever
#how many times did it fall
#how long did it stay each time

# %%
directory="altman_z_all.xlsx"
import pandas as pd
import numpy as np

# %%
#data=pd.read_excel(directory,encoding="latin-1", skiprows = [0,1,2,4], na_values = "#N/A N/A", sheet_name = "Sheet1", index_col = 0, header = None).dropna(axis = 1, how = "all").T

# %%
cols = pd.read_excel(directory, encoding="latin-1", skiprows = [0,1,2,4,5], na_values = ["#N/A N/A", "#N/A Review"], sheet_name = "Sheet1", header=None, nrows=1, index_col = 0).values[0]
data_r = pd.read_excel(directory, encoding="latin-1", skiprows = [0,1,2,4,5], na_values = ["#N/A N/A", "#N/A Review"], sheet_name = "Sheet1", index_col = 0).astype(np.float64)
data_r.columns = cols
data=data_r.dropna(axis=1,how="all")
data = data.loc[:,~data.columns.duplicated()]
dataT=data.T
display(data)
# Out:
#             AAPL UW Equity  BA UN Equity  CAT UN Equity  CSCO UW Equity  \
# 2000-03-31             NaN           NaN            NaN             NaN
# 2000-06-30             NaN           NaN            NaN             NaN
# 2000-09-29          4.4231           NaN            NaN         43.6708
# 2000-12-29          3.5875        3.1656         1.9380         35.2297
# 2001-03-30          4.0048        3.1580         1.8400         28.2265
# ...                    ...           ...            ...             ...
# 2019-06-28          4.2856        2.5734         2.7517          4.3370
# 2019-09-30          4.1762        2.5033         2.7429          4.0302
# 2019-12-31          4.8997        1.9765         2.8107          4.0210
# 2020-03-31          4.5233        1.4045         2.6521          4.3360
# 2020-06-30          4.5233        1.4045         2.6521          3.9004
#
#             CVX UN Equity  DIS UN Equity  DOW UN Equity  HD UN Equity  \
# 2000-03-31            NaN            NaN            NaN       20.1399
# 2000-06-30            NaN            NaN            NaN       20.1399
# 2000-09-29            NaN            NaN            NaN       20.1399
# 2000-12-29         3.4719            NaN            NaN       12.4573
# 2001-03-30         5.0354         3.4913            NaN       13.4790
# ...                   ...            ...            ...           ...
# 2019-06-28         3.2847         2.8412         2.2832        7.1234
# 2019-09-30         3.1464         3.3574         2.1779        7.3263
# 2019-12-31         3.1449         3.3005         2.0196        7.6374
# 2020-03-31         2.5274         2.6305         1.7700        7.5781
# 2020-06-30         2.5274         2.6305         1.8280        6.5338
#
#             IBM UN Equity  INTC UW Equity  ...  TFG SJ Equity  TGO SJ Equity  \
# 2000-03-31            NaN             NaN  ...            NaN            NaN
# 2000-06-30            NaN             NaN  ...            NaN            NaN
# 2000-09-29            NaN             NaN  ...            NaN            NaN
# 2000-12-29         3.2532         14.5086  ...            NaN            NaN
# 2001-03-30         3.3987         14.2808  ...         3.0423            NaN
# ...                   ...             ...  ...            ...            ...
# 2019-06-28         3.8275          4.6974  ...         4.6368            NaN
# 2019-09-30         5.0618          4.4841  ...         3.4166         0.5816
# 2019-12-31         4.8462          4.9806  ...         3.4166         0.5816
# 2020-03-31         4.5016          4.1601  ...         2.7010         0.5941
# 2020-06-30         4.5190          4.4275  ...         2.7010         0.5941
#
#             TKG SJ Equity  TRU SJ Equity  TSG SJ Equity  TXT SJ Equity  \
# 2000-03-31            NaN            NaN            NaN            NaN
# 2000-06-30            NaN            NaN            NaN            NaN
# 2000-09-29            NaN            NaN            NaN            NaN
# 2000-12-29            NaN            NaN            NaN            NaN
# 2001-03-30            NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 2019-06-28         2.7638         8.3174         1.9890         0.5303
# 2019-09-30         2.3544         8.3174         1.0871         0.6091
# 2019-12-31         2.3544         4.0866         1.0871         0.6322
# 2020-03-31         1.6393         4.0866         1.0296         0.6102
# 2020-06-30         1.6393         4.0866         1.0296         0.6102
#
#             VKE SJ Equity  VOD SJ Equity  WBO SJ Equity  WHL SJ Equity
# 2000-03-31            NaN            NaN            NaN            NaN
# 2000-06-30            NaN            NaN            NaN            NaN
# 2000-09-29            NaN            NaN            NaN            NaN
# 2000-12-29            NaN            NaN            NaN            NaN
# 2001-03-30            NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 2019-06-28         1.1043         3.2686         3.0382         4.3148
# 2019-09-30         1.0201         2.9063         3.0382         4.3148
# 2019-12-31         1.0201         2.9063         3.7696         2.1450
# 2020-03-31         0.4992         2.7143         3.7696         2.1450
# 2020-06-30         0.4992         2.7143         3.7696         2.1450
#
# [82 rows x 6156 columns]

# %%
data_lower = data.where(data<=1.8)
data_lower = data_lower.dropna(axis=1,how="all")
#data_lower.to_csv("data_lower.csv")

columns_to_keep=list(data_lower.columns)
data_filtered=data.filter(columns_to_keep,axis=1)
display(data_filtered)
# Out:
#             BA UN Equity  CAT UN Equity  CVX UN Equity  DOW UN Equity  \
# 2000-03-31           NaN            NaN            NaN            NaN
# 2000-06-30           NaN            NaN            NaN            NaN
# 2000-09-29           NaN            NaN            NaN            NaN
# 2000-12-29        3.1656         1.9380         3.4719            NaN
# 2001-03-30        3.1580         1.8400         5.0354            NaN
# ...                  ...            ...            ...            ...
# 2019-06-28        2.5734         2.7517         3.2847         2.2832
# 2019-09-30        2.5033         2.7429         3.1464         2.1779
# 2019-12-31        1.9765         2.8107         3.1449         2.0196
# 2020-03-31        1.4045         2.6521         2.5274         1.7700
# 2020-06-30        1.4045         2.6521         2.5274         1.8280
#
#             VZ UN Equity  1COV GY Equity  BAYN GY Equity  BMW GY Equity  \
# 2000-03-31           NaN             NaN             NaN            NaN
# 2000-06-30           NaN             NaN             NaN            NaN
# 2000-09-29           NaN             NaN             NaN            NaN
# 2000-12-29        1.6739             NaN             NaN            NaN
# 2001-03-30        1.5789             NaN          3.0633            NaN
# ...                  ...             ...             ...            ...
# 2019-06-28        2.3824          2.7582          2.5566         1.1596
# 2019-09-30        2.4387          3.1012          2.4250         1.1394
# 2019-12-31        2.4942          2.5134          2.5539         1.1811
# 2020-03-31        2.3781          2.6337          3.0956         1.1707
# 2020-06-30        2.4488          1.9353          3.0956         1.1707
#
#             CON GY Equity  DAI GY Equity  ...  SSW SJ Equity  STP SJ Equity  \
# 2000-03-31            NaN            NaN  ...            NaN            NaN
# 2000-06-30            NaN            NaN  ...            NaN            NaN
# 2000-09-29            NaN            NaN  ...            NaN            NaN
# 2000-12-29            NaN            NaN  ...            NaN            NaN
# 2001-03-30         2.3551            NaN  ...            NaN            NaN
# ...                   ...            ...  ...            ...            ...
# 2019-06-28         2.8367         1.0932  ...         0.7997         1.0466
# 2019-09-30         2.4193         1.1058  ...         0.7997         1.0055
# 2019-12-31         2.3175         1.1012  ...         1.8415         1.0055
# 2020-03-31         2.1120         1.0207  ...         1.8415         1.3498
# 2020-06-30         2.1120         0.9930  ...         1.8415         1.3498
#
#             SUI SJ Equity  TFG SJ Equity  TGO SJ Equity  TKG SJ Equity  \
# 2000-03-31            NaN            NaN            NaN            NaN
# 2000-06-30            NaN            NaN            NaN            NaN
# 2000-09-29            NaN            NaN            NaN            NaN
# 2000-12-29            NaN            NaN            NaN            NaN
# 2001-03-30            NaN         3.0423            NaN            NaN
# ...                   ...            ...            ...            ...
# 2019-06-28         1.1528         4.6368            NaN         2.7638
# 2019-09-30         1.1528         3.4166         0.5816         2.3544
# 2019-12-31         1.5705         3.4166         0.5816         2.3544
# 2020-03-31         1.5705         2.7010         0.5941         1.6393
# 2020-06-30         1.5705         2.7010         0.5941         1.6393
#
#             TSG SJ Equity  TXT SJ Equity  VKE SJ Equity  WBO SJ Equity
# 2000-03-31            NaN            NaN            NaN            NaN
# 2000-06-30            NaN            NaN            NaN            NaN
# 2000-09-29            NaN            NaN            NaN            NaN
# 2000-12-29            NaN            NaN            NaN            NaN
# 2001-03-30            NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 2019-06-28         1.9890         0.5303         1.1043         3.0382
# 2019-09-30         1.0871         0.6091         1.0201         3.0382
# 2019-12-31         1.0871         0.6322         1.0201         3.7696
# 2020-03-31         1.0296         0.6102         0.4992         3.7696
# 2020-06-30         1.0296         0.6102         0.4992         3.7696
#
# [82 rows x 3971 columns]

# %%
data_test = data_lower

# %%
data_lower

# %%
data_test = data_lower.notna().applymap(lambda x: 1 if x else 0)
data_test
# Out:
#             BA UN Equity  CAT UN Equity  CVX UN Equity  DOW UN Equity  \
# 2000-03-31             0              0              0              0
# 2000-06-30             0              0              0              0
# 2000-09-29             0              0              0              0
# 2000-12-29             0              0              0              0
# 2001-03-30             0              0              0              0
# ...                  ...            ...            ...            ...
# 2019-06-28             0              0              0              0
# 2019-09-30             0              0              0              0
# 2019-12-31             0              0              0              0
# 2020-03-31             1              0              0              1
# 2020-06-30             1              0              0              0
#
#             VZ UN Equity  1COV GY Equity  BAYN GY Equity  BMW GY Equity  \
# 2000-03-31             0               0               0              0
# 2000-06-30             0               0               0              0
# 2000-09-29             0               0               0              0
# 2000-12-29             1               0               0              0
# 2001-03-30             1               0               0              0
# ...                  ...             ...             ...            ...
# 2019-06-28             0               0               0              1
# 2019-09-30             0               0               0              1
# 2019-12-31             0               0               0              1
# 2020-03-31             0               0               0              1
# 2020-06-30             0               0               0              1
#
#             CON GY Equity  DAI GY Equity  ...  SSW SJ Equity  STP SJ Equity  \
# 2000-03-31              0              0  ...              0              0
# 2000-06-30              0              0  ...              0              0
# 2000-09-29              0              0  ...              0              0
# 2000-12-29              0              0  ...              0              0
# 2001-03-30              0              0  ...              0              0
# ...                   ...            ...  ...            ...            ...
# 2019-06-28              0              1  ...              1              1
# 2019-09-30              0              1  ...              1              1
# 2019-12-31              0              1  ...              0              1
# 2020-03-31              0              1  ...              0              1
# 2020-06-30              0              1  ...              0              1
#
#             SUI SJ Equity  TFG SJ Equity  TGO SJ Equity  TKG SJ Equity  \
# 2000-03-31              0              0              0              0
# 2000-06-30              0              0              0              0
# 2000-09-29              0              0              0              0
# 2000-12-29              0              0              0              0
# 2001-03-30              0              0              0              0
# ...                   ...            ...            ...            ...
# 2019-06-28              1              0              0              0
# 2019-09-30              1              0              1              0
# 2019-12-31              1              0              1              0
# 2020-03-31              1              0              1              1
# 2020-06-30              1              0              1              1
#
#             TSG SJ Equity  TXT SJ Equity  VKE SJ Equity  WBO SJ Equity
# 2000-03-31              0              0              0              0
# 2000-06-30              0              0              0              0
# 2000-09-29              0              0              0              0
# 2000-12-29              0              0              0              0
# 2001-03-30              0              0              0              0
# ...                   ...            ...            ...            ...
# 2019-06-28              0              1              1              0
# 2019-09-30              1              1              1              0
# 2019-12-31              1              1              1              0
# 2020-03-31              1              1              1              0
# 2020-06-30              1              1              1              0
#
# [82 rows x 3971 columns]

# %%
data_test_applied = data_test.apply(lambda y: y * (y.groupby((y != y.shift()).cumsum()).cumcount() + 1))

# %%
#data_test_applied.to_csv("counted_list.csv")

# %%
#The longest these companies have stayed below altman-z-score of 1.8
longest_under = data_test_applied.apply(lambda x: x.max()).sort_values(ascending = False).to_frame()
longest_under
# Out:
#                  0
# ASUR UR Equity  80
# PNM UN Equity   79
# WEC UN Equity   79
# NI UN Equity    79
# SO UN Equity    79
# ...             ..
# 3139 JT Equity   1
# 3116 JT Equity   1
# 3079 JT Equity   1
# 3036 JT Equity   1
# ADEN SW Equity   1
#
# [3971 rows x 1 columns]

# %%
#prototype for seeing the length of the consecutive quarters below 1.8
data_first_time = data_test_applied["SO UN Equity"].value_counts().sort_values().to_frame()
display(data_first_time)
# Out:
#     SO UN Equity
# 38             1
# 76             1
# 75             1
# 74             1
# 73             1
# ..           ...
# 1              1
# 8              1
# 18             1
# 57             1
# 0              3
#
# [80 rows x 1 columns]

# %%
#prototype: number of times the company first fell below 1.8
data_falls = len(data_test_applied[data_test_applied["SO UN Equity"] == 1])
data_falls
# Out:
# 1
